# %%
import pandas as pd

# %%
# Read in data set
movies_df = pd.read_csv('movies_metadata.csv', low_memory=False)
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# The following cell uses a function `more_than_15_words` to select the rows from `movies_df` that have titles with more than 15 words. In the next cell, do the same selection, but using a lambda function

# %%
def more_than_15_words(title):
    split_title = title.split() # split the title into a list of words
    number_of_words_in_title = len(split_title) # count the number of words in the title
    is_greater_than_15 = number_of_words_in_title > 15 # check if the number of words is greater than 15
    return is_greater_than_15 # return whether or not the title has more than 15 words

movies_df[movies_df['original_title'].map(more_than_15_words)]
# Out:
#        adult belongs_to_collection   budget  \
# 7241   False                   NaN  5600000
# 7268   False                   NaN        0
# 8420   False                   NaN        0
# 9227   False                   NaN        0
# 14093  False                   NaN        0
# 36826  False                   NaN        0
# 38511  False                   NaN        0
# 38514  False                   NaN        0
# 38515  False                   NaN        0
# 44215  False                   NaN        0
#
#                                                   genres homepage      id  \
# 7241   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   10338
# 7268   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   65332
# 8420   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   22638
# 9227                                                  []      NaN   22616
# 14093  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   36108
# 36826                [{'id': 99, 'name': 'Documentary'}]      NaN  270936
# 38511                [{'id': 99, 'name': 'Documentary'}]      NaN  132144
# 38514                [{'id': 99, 'name': 'Documentary'}]      NaN  132148
# 38515                [{'id': 99, 'name': 'Documentary'}]      NaN  132150
# 44215                  [{'id': 12, 'name': 'Adventure'}]      NaN   85854
#
#          imdb_id original_language  \
# 7241   tt0059797                en
# 7268   tt0070061                it
# 8420   tt0036910                en
# 9227   tt0230575                en
# 14093  tt0973844                en
# 36826  tt1023446                en
# 38511  tt0072685                es
# 38514  tt0074187                es
# 38515  tt0078831                es
# 44215  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36826  Ellen ten Damme: As I Was Wondering Where This...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38514  La batalla de Chile: La lucha de un pueblo sin...
# 38515  La batalla de Chile: La lucha de un pueblo sin...
# 44215  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview  ... release_date  \
# 7241   Star studded comedy about a early 20th century...  ...   1965-06-03
# 7268   Set in Fascist Italy before the outbreak of Wo...  ...   1973-02-23
# 8420   Olivier mustered out of the navy to film this ...  ...   1944-11-24
# 9227   The makers of this parody of "Night of the Liv...  ...   1991-01-01
# 14093  A collective film of 33 shorts directed by dif...  ...   2007-05-19
# 36826  Documentary about Dutch artist Ellen ten Damme...  ...   2007-04-19
# 38511  Documents the rise of the right-wing movement ...  ...   1975-03-18
# 38514  Chronicles the events immediately surrounding ...  ...   1976-03-13
# 38515  Guzmán’s final instalment shifts from covering...  ...   1979-03-15
# 44215  A group of lonely Viking women build a ship an...  ...   1957-12-01
#
#           revenue runtime                                   spoken_languages  \
# 7241   29950000.0   138.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 7268          0.0   120.0          [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 8420          0.0   137.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 9227          0.0    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14093         0.0   100.0  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...
# 36826         0.0    66.0                                                 []
# 38511         0.0    97.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 38514         0.0    88.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 38515         0.0    78.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 44215         0.0    66.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 7241   Released  or How I Flew from London to Paris in 25 hours...
# 7268   Released                                                NaN
# 8420   Released                                                NaN
# 9227   Released                                                NaN
# 14093  Released                                                NaN
# 36826  Released                                                NaN
# 38511  Released                                                NaN
# 38514  Released                                                NaN
# 38515  Released                                                NaN
# 44215  Released  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False          6.4
# 7268                                    Love and Anarchy  False          7.0
# 8420                                             Henry V  False          7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False          5.3
# 14093                             To Each His Own Cinema  False          7.2
# 36826  Ellen ten Damme: As I Was Wondering Where This...  False          0.0
# 38511                       The Battle of Chile - Part I  False          6.3
# 38514                      The Battle of Chile - Part II  False          6.8
# 38515                     The Battle of Chile - Part III  False          6.0
# 44215  The Saga of the Viking Women and Their Voyage ...  False          2.0
#
#       vote_count
# 7241        40.0
# 7268         8.0
# 8420        25.0
# 9227         4.0
# 14093       26.0
# 36826        0.0
# 38511        4.0
# 38514        4.0
# 38515        3.0
# 44215        3.0
#
# [10 rows x 24 columns]

# %%
# Find all the movies that have more than 15 words in their title using a lambda function.
# YOUR CODE HERE
query_filter = movies_df['original_title'].map(lambda title:len(title.split())>15)

movies_df[query_filter]
# Out:
#        adult belongs_to_collection   budget  \
# 7241   False                   NaN  5600000
# 7268   False                   NaN        0
# 8420   False                   NaN        0
# 9227   False                   NaN        0
# 14093  False                   NaN        0
# 36826  False                   NaN        0
# 38511  False                   NaN        0
# 38514  False                   NaN        0
# 38515  False                   NaN        0
# 44215  False                   NaN        0
#
#                                                   genres homepage      id  \
# 7241   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   10338
# 7268   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   65332
# 8420   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   22638
# 9227                                                  []      NaN   22616
# 14093  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   36108
# 36826                [{'id': 99, 'name': 'Documentary'}]      NaN  270936
# 38511                [{'id': 99, 'name': 'Documentary'}]      NaN  132144
# 38514                [{'id': 99, 'name': 'Documentary'}]      NaN  132148
# 38515                [{'id': 99, 'name': 'Documentary'}]      NaN  132150
# 44215                  [{'id': 12, 'name': 'Adventure'}]      NaN   85854
#
#          imdb_id original_language  \
# 7241   tt0059797                en
# 7268   tt0070061                it
# 8420   tt0036910                en
# 9227   tt0230575                en
# 14093  tt0973844                en
# 36826  tt1023446                en
# 38511  tt0072685                es
# 38514  tt0074187                es
# 38515  tt0078831                es
# 44215  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36826  Ellen ten Damme: As I Was Wondering Where This...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38514  La batalla de Chile: La lucha de un pueblo sin...
# 38515  La batalla de Chile: La lucha de un pueblo sin...
# 44215  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview  ... release_date  \
# 7241   Star studded comedy about a early 20th century...  ...   1965-06-03
# 7268   Set in Fascist Italy before the outbreak of Wo...  ...   1973-02-23
# 8420   Olivier mustered out of the navy to film this ...  ...   1944-11-24
# 9227   The makers of this parody of "Night of the Liv...  ...   1991-01-01
# 14093  A collective film of 33 shorts directed by dif...  ...   2007-05-19
# 36826  Documentary about Dutch artist Ellen ten Damme...  ...   2007-04-19
# 38511  Documents the rise of the right-wing movement ...  ...   1975-03-18
# 38514  Chronicles the events immediately surrounding ...  ...   1976-03-13
# 38515  Guzmán’s final instalment shifts from covering...  ...   1979-03-15
# 44215  A group of lonely Viking women build a ship an...  ...   1957-12-01
#
#           revenue runtime                                   spoken_languages  \
# 7241   29950000.0   138.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 7268          0.0   120.0          [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 8420          0.0   137.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 9227          0.0    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14093         0.0   100.0  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...
# 36826         0.0    66.0                                                 []
# 38511         0.0    97.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 38514         0.0    88.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 38515         0.0    78.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 44215         0.0    66.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 7241   Released  or How I Flew from London to Paris in 25 hours...
# 7268   Released                                                NaN
# 8420   Released                                                NaN
# 9227   Released                                                NaN
# 14093  Released                                                NaN
# 36826  Released                                                NaN
# 38511  Released                                                NaN
# 38514  Released                                                NaN
# 38515  Released                                                NaN
# 44215  Released  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False          6.4
# 7268                                    Love and Anarchy  False          7.0
# 8420                                             Henry V  False          7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False          5.3
# 14093                             To Each His Own Cinema  False          7.2
# 36826  Ellen ten Damme: As I Was Wondering Where This...  False          0.0
# 38511                       The Battle of Chile - Part I  False          6.3
# 38514                      The Battle of Chile - Part II  False          6.8
# 38515                     The Battle of Chile - Part III  False          6.0
# 44215  The Saga of the Viking Women and Their Voyage ...  False          2.0
#
#       vote_count
# 7241        40.0
# 7268         8.0
# 8420        25.0
# 9227         4.0
# 14093       26.0
# 36826        0.0
# 38511        4.0
# 38514        4.0
# 38515        3.0
# 44215        3.0
#
# [10 rows x 24 columns]

# %%
def hundredfold_return(row):
    revenue = row['revenue']
    budget = row['budget']
    budget_over_1000 = budget > 1000
    revenue_over_100x = revenue > 100 * budget
    return revenue_over_100x and budget_over_1000
    
movies_df[movies_df.apply(hundredfold_return, axis=1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12688\2244556531.py in <module>
#       6     return revenue_over_100x and budget_over_1000
#       7
# ----> 8 movies_df[movies_df.apply(hundredfold_return, axis=1)]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp\ipykernel_12688\2244556531.py in hundredfold_return(row)
#       2     revenue = row['revenue']
#       3     budget = row['budget']
# ----> 4     budget_over_1000 = budget > 1000
#       5     revenue_over_100x = revenue > 100 * budget
#       6     return revenue_over_100x and budget_over_1000
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# Find all movies with budgets over 1000 that pulled in revenue over 100x their budget using a lambda function
# YOUR CODE HERE

# %%
# load in list of English words
words_file = '../Resources/words.txt'

words_df = pd.read_csv(words_file, sep='\n', header=None)
words_df.columns = ['text']
words_df.head()
# Out:
#   text
# 0  the
# 1   of
# 2  and
# 3   to
# 4    a

# %%
def contains_x(word):
    split_word = list(word)
    word_contains_x = 'x' in split_word
    return word_contains_x

words_df[words_df['text'].map(contains_x)]
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]

# %%
# Find all words containing the letter 'x' using a lambda function
# YOUR CODE HERE
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]
